# %%
import pandas as pd
import os 
TRAINING_DATA_PATH = os.path.join(".","input_data")
def load_training_data(training_data_path=TRAINING_DATA_PATH):
    csv_path = os.path.join(training_data_path, "train_V2.csv")
    return pd.read_csv(csv_path)

# %%
training = load_training_data()
training.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace      ...       revives  \
# 0         0.00      0              0      0         60      ...             0
# 1        91.47      0              0      0         57      ...             0
# 2        68.00      0              0      0         47      ...             0
# 3        32.90      0              0      0         75      ...             0
# 4       100.00      0              0      0         45      ...             0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# ...

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
# Id                 object
# groupId            object
# matchId            object
# assists            int64
# boosts             int64
# damageDealt        float64
# DBNOs              int64
# headshotKills      int64
# heals              int64
# killPlace          int64
# killPoints         int64
# kills              int64
# killStreaks        int64
# longestKill        float64
# matchDuration      int64
# matchType          object
# maxPlace           int64
# numGroups          int64
# rankPoints         int64
# revives            int64
# rideDistance       float64
# roadKills          int64
# swimDistance       float64
# teamKills          int64
# vehicleDestroys    int64
# walkDistance       float64
# weaponsAcquired    int64
# winPoints          int64
# winPlacePerc       float64
# dtypes: float64(6), int64(19), object(4)
# memory usage: 983.9+ MB

# %%
training["matchType"].value_counts()
# Out:
# squad-fpp           1756186
# duo-fpp              996691
# squad                626526
# solo-fpp             536762
# duo                  313591
# solo                 181943
# normal-squad-fpp      17174
# crashfpp               6287
# normal-duo-fpp         5489
# flaretpp               2505
# normal-solo-fpp        1682
# flarefpp                718
# normal-squad            516
# crashtpp                371
# normal-solo             326
# normal-duo              199
# Name: matchType, dtype: int64

# %%
training.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06   4.446966e+06
# mean   2.338149e-01  1.106908e+00  1.307171e+02  6.578755e-01   2.268196e-01
# std    5.885731e-01  1.715794e+00  1.707806e+02  1.145743e+00   6.021553e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.424000e+01  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.860000e+02  1.000000e+00   0.000000e+00
# max    2.200000e+01  3.300000e+01  6.616000e+03  5.300000e+01   6.400000e+01
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06
# mean   1.370147e+00  4.759935e+01  5.050060e+02  9.247833e-01  5.439551e-01
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
training.hist(bins=50, figsize=(20,20))
plt.show()

# %%
# %matplotlib inline
training.plot(kind="scatter", x="killStreaks", y="kills")

# %%
training.plot(kind="scatter", x="killStreaks", y="longestKill")

# %%
training.plot(kind="scatter", x="roadKills", y="rideDistance")

# %%
training.plot(kind="scatter", x="walkDistance", y="weaponsAcquired")

# %%
training.plot(kind="scatter", x="walkDistance", y="weaponsAcquired",alpha=0.1)

# %%
training.plot(kind="scatter", x="revives", y="rankPoints", alpha=0.1)

# %%
training.plot(kind="scatter", x="vehicleDestroys", y="roadKills", alpha=0.1)

# %%
training.plot(kind="scatter", x="kills", y="winPoints", alpha=0.1)

# %%
training.plot(kind="scatter", x="winPlacePerc", y="kills", alpha=0.1)

# %%
training.plot(kind="scatter", x="winPlacePerc", y="winPoints", alpha=0.1)

# %%
training.plot(kind="scatter", x="rideDistance", y="swimDistance", alpha=0.1)

# %%
training.plot(kind="scatter", x="kills", y="weaponsAcquired",alpha=0.1)

# %%
from pandas.plotting import scatter_matrix
attributes = ["kills", "revives", "winPlacePerc",
"heals"]
scatter_matrix(training[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd6c306710>,
# ...
#       dtype=object)

# %%
corr_matrix = training.corr()

# %%
corr_matrix["winPlacePerc"].sort_values(ascending=False)
# Out:
# winPlacePerc       1.000000
# walkDistance       0.810888
# boosts             0.634234
# weaponsAcquired    0.583806
# damageDealt        0.440507
# heals              0.427857
# kills              0.419916
# longestKill        0.410154
# killStreaks        0.377566
# rideDistance       0.342915
# assists            0.299441
# DBNOs              0.279970
# headshotKills      0.277722
# revives            0.240881
# swimDistance       0.149607
# vehicleDestroys    0.073436
# numGroups          0.039621
# maxPlace           0.037377
# roadKills          0.034544
# teamKills          0.015943
# rankPoints         0.013523
# killPoints         0.012908
# winPoints          0.007061
# matchDuration     -0.005171
# killPlace         -0.719069
# Name: winPlacePerc, dtype: float64

# %%
corr_matrix["winPoints"].sort_values(ascending=False)
# Out:
# winPoints          1.000000
# killPoints         0.983417
# assists            0.024014
# damageDealt        0.017762
# DBNOs              0.011108
# killStreaks        0.008552
# winPlacePerc       0.007061
# kills              0.006929
# headshotKills      0.004982
# revives            0.002434
# walkDistance      -0.002043
# killPlace         -0.002415
# swimDistance      -0.002680
# longestKill       -0.003720
# weaponsAcquired   -0.003815
# roadKills         -0.004750
# boosts            -0.007644
# heals             -0.010990
# vehicleDestroys   -0.011426
# numGroups         -0.027483
# rideDistance      -0.027809
# maxPlace          -0.029295
# teamKills         -0.040943
# matchDuration     -0.087360
# rankPoints        -0.993845
# Name: winPoints, dtype: float64
